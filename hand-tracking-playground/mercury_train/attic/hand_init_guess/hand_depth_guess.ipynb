# %%
import sympy


def norm(x,y,z):
  return sympy.sqrt(x**2, y**2, z**2)

distance, midpxm_bearing, extra_depth, hand_size = sympy.symbols('distance, midpxm_bearing, extra_depth, hand_size')


sympy.solve(norm())

# %%
aa, d, c, h = sympy.symbols("angle,distance,wrist_extra_distance_meters,hand_size")

exp = sympy.Eq(aa, ((d+c)**2 + d**2 - h**2)/(2* (d+c) * d))
sympy.ccode(sympy.solve(exp, d))

# %% [markdown]
# TODO Take a picture of your notebook page where you figured this out! I can't really figure out how this works off the top of my head.
